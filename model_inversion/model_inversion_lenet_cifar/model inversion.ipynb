# %%
cd "drive/MyDrive/model inversion(lenet)"
# Out:
# /content/drive/MyDrive/model inversion(lenet)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

class Extractor(nn.Module):

    def __init__(self):
        super(Extractor, self).__init__()
        self.extractor = nn.Sequential(
            nn.Conv2d(1, 6, 5),
            nn.AvgPool2d(2, 2),
            nn.Sigmoid(),
            nn.Conv2d(6, 16, 5),
            nn.AvgPool2d(2, 2),
            nn.Sigmoid(),
        )

    def forward(self, x):
        x = self.extractor(x)
        return x

    
class Classifier(nn.Module):

    def __init__(self, num_classes=10):
        super(Classifier, self).__init__()
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(16 * 5 * 5, 120),
            nn.Sigmoid(),
            nn.Linear(120, 84),
            nn.Sigmoid(),
            nn.Linear(84, num_classes),
        )

    def forward(self, x):
        x = self.classifier(x)
        return x


class Generator(nn.Module):

    def __init__(self):
        super(Generator, self).__init__()
        self.generator = nn.Sequential(
            nn.ConvTranspose2d(100 + 10, 512, 2, 1, 0),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(512, 256, 2, 1, 0),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(256, 128, 2, 1, 0),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 16, 2, 1, 0),
            nn.Sigmoid(),
        )
        self.apply(weights_init)
        
    def forward(self, z, y):
        y = F.one_hot(y, 10)
        y = y.unsqueeze(-1).unsqueeze(-1)
        feat = torch.cat([z, y], 1)
        feat = self.generator(feat)
        return feat
    
    
class Discriminator(nn.Module):

    def __init__(self):
        super(Discriminator, self).__init__()
        self.discriminator = nn.Sequential(
            nn.Conv2d(16 + 10, 128, 2, 1, 0),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(128, 256, 2, 1, 0),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(256, 512, 2, 1, 0),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(inplace=True),
            nn.Conv2d(512, 1, 2, 1, 0),
            nn.Sigmoid(),
        )
        self.apply(weights_init)
        
    def forward(self, feat, y):
        y = F.one_hot(y, 10)
        y = y.unsqueeze(-1).unsqueeze(-1)
        y = y.expand(y.size(0), 10, 5, 5)
        feat = torch.cat([feat, y], 1)
        feat = self.discriminator(feat)
        feat = feat.squeeze(-1).squeeze(-1)
        return feat

# %%
from torch.utils.data import Dataset, DataLoader, Subset
from torchvision import transforms
import torchvision.datasets as datasets
import numpy as np

transform=transforms.Compose([
    transforms.Resize([32, 32]),
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5)),
])

usps_trainset = datasets.USPS(root='./data', train=True, download=True, transform=transform)
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

size = len(usps_trainset)
index = np.arange(size)
client_trainset = Subset(usps_trainset, index[:2000])

client_trainloader = DataLoader(client_trainset, batch_size=1, shuffle=False, num_workers=0, pin_memory=True)

# %%
import matplotlib.pyplot as plt  

def get_params(net, modules):
    params = []
    for module in modules:
        params.append({"params": net[module].parameters()})
    return params

def frozen_net(net, modules, frozen):
    for module in modules:
        for param in net[module].parameters():
            param.requires_grad = not frozen
        if frozen:
            net[module].eval()
        else:
            net[module].train()

def total_variation_loss(image):
    bs, c, h, w = image.size()
    tv_h = torch.pow(image[:,:,1:,:] - image[:,:,:-1,:], 2).sum()
    tv_w = torch.pow(image[:,:,:,1:] - image[:,:,:,:-1], 2).sum()
    return (tv_h + tv_w) / (bs * c * h * w)



def show_image(image):
    image = image[0][0]  # [bs, 1, 32, 32] -> [32, 32]
    # image = image.permute(1, 2, 0)
    image = image.cpu().detach().numpy()
    image = (image+1)/2  # [-1,1] -> [0,1]
    plt.imshow(image, cmap='gray')


def cal_psnr(real_image, inversion_image):
    mse = ((real_image - inversion_image) ** 2).mean()
    mse = mse.cpu().detach().numpy()
    psnr = 10 * np.log10(4/mse)
    return psnr

# %% [markdown]
# **客户端的真实feature**

# %%
net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/client_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

iteration = iter(client_trainloader)

# 图片和标签（全局变量，不要覆盖）
image, label = next(iteration)

# 真实特征（全局变量，不要覆盖）
real_feature = net["extractor"](image).detach()

show_image(image)

# %% [markdown]
# **定义model inversion函数**

# %%
def model_inversion(net, feature, lambda_tv):
    x = torch.zeros((1, 1, 32, 32))
    x.requires_grad = True
    x_optimizer = optim.Adam(params=[x], lr=1e-3)

    feature_mses, image_tvs, image_mses = [], [], []
    epoch, prev_image_mse = 0, 4.
    converge_flag = False

    while True:
        x_optimizer.zero_grad()
        inversion_feature = net["extractor"](x)
        feature_mse = ((feature - inversion_feature) ** 2).sum()
        image_tv = lambda_tv * total_variation_loss(x)
        loss = feature_mse + image_tv
        loss.backward()
        x_optimizer.step()

        with torch.no_grad():
            image_mse = ((image - x) ** 2).mean()

        feature_mses.append(feature_mse.item())
        image_tvs.append(image_tv.item())
        image_mses.append(image_mse.item())
        
        if epoch%1000 == 0:
            print("epoch:%4d, feature_mse:%2.6f, image_tv:%2.6f, image_mse:%2.6f"
                %(epoch, np.mean(feature_mses), np.mean(image_tvs), np.mean(image_mses)))
            
            # 收敛条件：image_mse减少量小于1e-6
            if prev_image_mse - np.mean(image_mses) < 1e-6:
                converge_flag = True
            else:
                prev_image_mse = np.mean(image_mses)
            feature_mses, image_tvs, image_mses = [], [], []

        if converge_flag:
            break
        epoch += 1
    
    # 返回反推的图片
    return x

# %%
# 已知extractor，用真实feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/client_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

x = model_inversion(net, real_feature, lambda_tv=1e-4)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# epoch:   0, feature_mse:61.858936, image_tv:0.000000, image_mse:0.511230
# epoch:1000, feature_mse:13.783558, image_tv:0.000006, image_mse:0.347240
# epoch:2000, feature_mse:0.379738, image_tv:0.000014, image_mse:0.229492
# epoch:3000, feature_mse:0.093907, image_tv:0.000019, image_mse:0.187024
# epoch:4000, feature_mse:0.031243, image_tv:0.000023, image_mse:0.168406
# epoch:5000, feature_mse:0.011794, image_tv:0.000026, image_mse:0.159186
# epoch:6000, feature_mse:0.004885, image_tv:0.000027, image_mse:0.153500
# epoch:7000, feature_mse:0.002133, image_tv:0.000028, image_mse:0.148639
# epoch:8000, feature_mse:0.000975, image_tv:0.000029, image_mse:0.143488
# epoch:9000, feature_mse:0.000481, image_tv:0.000029, image_mse:0.137925
# epoch:10000, feature_mse:0.000259, image_tv:0.000029, image_mse:0.132243
# epoch:11000, feature_mse:0.000145, image_tv:0.000028, image_mse:0.126297
# epoch:12000, feature_mse:0.000082, image_tv:0.000027, image_mse:0.119435
# epoch:13000, feature_mse:0.000046, image_tv:0.000026, image_mse:0.110987
# epoch:14000, feature_mse:0.000026, image_tv:0.000024, image_mse:0.100486
# epoch:15000, feature_mse:0.000014, image_tv:0.000021, image_mse:0.087793
# epoch:16000, feature_mse:0.000007, image_tv:0.000018, image_mse:0.073434
# epoch:17000, feature_mse:0.000003, image_tv:0.000016, image_mse:0.058320
# epoch:18000, feature_mse:0.000002, image_tv:0.000013, image_mse:0.043555
# epoch:19000, feature_mse:0.000001, image_tv:0.000010, image_mse:0.030540
# epoch:20000, feature_mse:0.000001, image_tv:0.000009, image_mse:0.020612
# epoch:21000, feature_mse:0.000001, image_tv:0.000008, image_mse:0.014190
# epoch:22000, feature_mse:0.000001, image_tv:0.000007, image_mse:0.010617
# epoch:23000, feature_mse:0.000001, image_tv:0.000007, image_mse:0.008822
# epoch:24000, feature_mse:0.000001, image_tv:0.000007, image_mse:0.007902
# epoch:25000, feature_mse:0.000000, image_tv:0.000007, image_mse:0.007318
# epoch:26000, feature_mse:0.000000, image_tv:0.000007, image_mse:0.006869
# epoch:27000, feature_mse:0.000000, image_tv:0.000007, image_mse:0.006491
# epoch:28000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.006163
# epoch:29000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.005873
# epoch:30000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.005612
# epoch:31000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.005377
# epoch:32000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.005163
# epoch:33000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004967
# epoch:34000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004787
# epoch:35000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004621
# epoch:36000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004467
# epoch:37000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004325
# epoch:38000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004193
# epoch:39000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.004070
# epoch:40000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003954
# epoch:41000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003846
# epoch:42000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003745
# epoch:43000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003649
# epoch:44000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003559
# epoch:45000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003475
# epoch:46000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003395
# epoch:47000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003319
# epoch:48000, feature_mse:0.000000, image_tv:0.000006, image_mse:0.003248
# epoch:49000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.003181
# epoch:50000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.003117
# epoch:51000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.003056
# epoch:52000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002999
# epoch:53000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002944
# epoch:54000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002892
# epoch:55000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002842
# epoch:56000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002795
# epoch:57000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002751
# epoch:58000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002708
# epoch:59000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002667
# epoch:60000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002629
# epoch:61000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002592
# epoch:62000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002557
# epoch:63000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002523
# epoch:64000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002491
# epoch:65000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002460
# epoch:66000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002431
# epoch:67000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002402
# epoch:68000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002375
# epoch:69000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002350
# epoch:70000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002325
# epoch:71000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002301
# epoch:72000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002279
# epoch:73000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002257
# epoch:74000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002236
# epoch:75000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002216
# epoch:76000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002197
# epoch:77000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002178
# epoch:78000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002160
# epoch:79000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002143
# epoch:80000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002127
# epoch:81000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002111
# epoch:82000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002096
# epoch:83000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002082
# epoch:84000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002068
# epoch:85000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002054
# epoch:86000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002041
# epoch:87000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002029
# epoch:88000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002017
# epoch:89000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.002005
# epoch:90000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001994
# epoch:91000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001984
# epoch:92000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001973
# epoch:93000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001963
# epoch:94000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001954
# epoch:95000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001944
# epoch:96000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001935
# epoch:97000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001927
# epoch:98000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001918
# epoch:99000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001910
# epoch:100000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001903
# epoch:101000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001895
# epoch:102000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001888
# epoch:103000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001881
# epoch:104000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001874
# epoch:105000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001868
# epoch:106000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001861
# epoch:107000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001855
# epoch:108000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001849
# epoch:109000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001844
# epoch:110000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001838
# epoch:111000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001833
# epoch:112000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001828
# epoch:113000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001823
# epoch:114000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001818
# epoch:115000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001813
# epoch:116000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001809
# epoch:117000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001804
# epoch:118000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001800
# epoch:119000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001796
# epoch:120000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001792
# epoch:121000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001788
# epoch:122000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001785
# epoch:123000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001781
# epoch:124000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001777
# epoch:125000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001774
# epoch:126000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001771
# epoch:127000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001768
# epoch:128000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001765
# epoch:129000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001762
# epoch:130000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001759
# epoch:131000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001756
# epoch:132000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001753
# epoch:133000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001751
# epoch:134000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001748
# epoch:135000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001746
# epoch:136000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001743
# epoch:137000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001741
# epoch:138000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001739
# epoch:139000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001737
# epoch:140000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001734
# epoch:141000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001732
# epoch:142000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001730
# epoch:143000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001728
# epoch:144000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001727
# epoch:145000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001725
# epoch:146000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001723
# epoch:147000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001721
# epoch:148000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001720
# epoch:149000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001718
# epoch:150000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001717
# epoch:151000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001715
# epoch:152000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001714
# epoch:153000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001712
# epoch:154000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001711
# epoch:155000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001710
# epoch:156000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001708
# epoch:157000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001707
# epoch:158000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001706
# epoch:159000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001705
# epoch:160000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001703
# epoch:161000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001702
# epoch:162000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001701
# epoch:163000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001700
# epoch:164000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001699
# epoch:165000, feature_mse:0.000000, image_tv:0.000005, image_mse:0.001698
# psnr:33.721420

# %%
# 相同数据训练extractor，用真实feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/server_same_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

shadow_feature = net["extractor"](image).detach()
print( ((shadow_feature - real_feature) ** 2).sum() )

x = model_inversion(net, real_feature, lambda_tv=5)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# tensor(0.4888)
# epoch:   0, feature_mse:62.223946, image_tv:0.000000, image_mse:0.511265
# epoch:1000, feature_mse:14.867485, image_tv:0.164870, image_mse:0.310066
# epoch:2000, feature_mse:0.890800, image_tv:0.229892, image_mse:0.134910
# epoch:3000, feature_mse:0.467007, image_tv:0.213763, image_mse:0.077518
# epoch:4000, feature_mse:0.356734, image_tv:0.213964, image_mse:0.057329
# epoch:5000, feature_mse:0.314367, image_tv:0.218147, image_mse:0.051308
# epoch:6000, feature_mse:0.296078, image_tv:0.222153, image_mse:0.050465
# epoch:7000, feature_mse:0.288156, image_tv:0.225055, image_mse:0.051090
# psnr:18.905101

# %%
# 同分布数据训练extractor，用真实feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/server_iid_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

shadow_feature = net["extractor"](image).detach()
print( ((shadow_feature - real_feature) ** 2).sum() )

x = model_inversion(net, real_feature, lambda_tv=50)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# tensor(35.5461)
# epoch:   0, feature_mse:74.489571, image_tv:0.000000, image_mse:0.511279
# epoch:1000, feature_mse:35.715982, image_tv:0.782666, image_mse:0.369645
# epoch:2000, feature_mse:21.894577, image_tv:1.556137, image_mse:0.322067
# epoch:3000, feature_mse:20.739765, image_tv:1.910134, image_mse:0.344570
# psnr:10.479689

# %%
# 不同分布数据训练extractor，用真实feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/server_niid_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

shadow_feature = net["extractor"](image).detach()
print( ((shadow_feature - real_feature) ** 2).sum() )

x = model_inversion(net, real_feature, lambda_tv=50)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# tensor(56.8287)
# epoch:   0, feature_mse:65.377785, image_tv:0.000000, image_mse:0.511358
# epoch:1000, feature_mse:39.636205, image_tv:1.102432, image_mse:0.371673
# epoch:2000, feature_mse:28.172236, image_tv:2.407578, image_mse:0.308766
# epoch:3000, feature_mse:27.026717, image_tv:2.726459, image_mse:0.294994
# epoch:4000, feature_mse:26.614291, image_tv:3.011829, image_mse:0.303995
# psnr:11.116520

# %%
# z 和 image 配对 (最小化fake feature和real feature的mse)

net = nn.ModuleDict()
net["generator"] = Generator()            
frozen_net(net, ["generator"], True)

G_checkpoint = torch.load("./checkpoint/client_generator.pkl", map_location=torch.device('cpu'))
net["generator"].load_state_dict(G_checkpoint)

# 优化z
z = torch.zeros((1, 100, 1, 1))
z.requires_grad = True
z_optimizer = optim.Adam(params=[z], lr=1e-3)

feature_mses = []
epoch, prev_loss = 0, 10000.
converge_flag = False
while True:
    z_optimizer.zero_grad()
    inversion_feature = net["generator"](z, label)
    feature_mse = ((real_feature - inversion_feature) ** 2).sum()
    feature_mse.backward()
    z_optimizer.step()

    feature_mses.append(feature_mse.item())

    if epoch%1000 == 0:
        print("epoch:%4d, feature_mse:%2.6f"%(epoch, np.mean(feature_mses)))
        if prev_loss - np.mean(feature_mses) < 1e-6:
            converge_flag = True
        else:
            prev_loss = np.mean(feature_mses)
        feature_mses = []

    if converge_flag:
        break
    epoch += 1

# 最接近真实feature的虚假feature（全局变量，不要覆盖）
fake_feature = net["generator"](z, label).detach()
# Out:
# epoch:   0, feature_mse:34.189785
# epoch:1000, feature_mse:6.951728
# epoch:2000, feature_mse:2.253874
# epoch:3000, feature_mse:1.709658
# epoch:4000, feature_mse:1.424024
# epoch:5000, feature_mse:1.190999
# epoch:6000, feature_mse:1.021837
# epoch:7000, feature_mse:0.898690
# epoch:8000, feature_mse:0.815004
# epoch:9000, feature_mse:0.745438
# epoch:10000, feature_mse:0.691329
# epoch:11000, feature_mse:0.649852
# epoch:12000, feature_mse:0.612465
# epoch:13000, feature_mse:0.584217
# epoch:14000, feature_mse:0.568060
# epoch:15000, feature_mse:0.563125
# epoch:16000, feature_mse:0.558515
# epoch:17000, feature_mse:0.553263
# epoch:18000, feature_mse:0.550040
# epoch:19000, feature_mse:0.547780
# epoch:20000, feature_mse:0.547050
# epoch:21000, feature_mse:0.546638
# epoch:22000, feature_mse:0.546238
# epoch:23000, feature_mse:0.545857
# epoch:24000, feature_mse:0.545705
# epoch:25000, feature_mse:0.545554
# epoch:26000, feature_mse:0.545320
# epoch:27000, feature_mse:0.545218
# epoch:28000, feature_mse:0.545193
# epoch:29000, feature_mse:0.545175
# epoch:30000, feature_mse:0.545170
# epoch:31000, feature_mse:0.545167
# epoch:32000, feature_mse:0.545169

# %%
# 已知extractor，用虚假feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/client_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

x = model_inversion(net, fake_feature, lambda_tv=5)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# epoch:   0, feature_mse:60.413013, image_tv:0.000000, image_mse:0.511220
# epoch:1000, feature_mse:13.599442, image_tv:0.166001, image_mse:0.327813
# epoch:2000, feature_mse:0.597463, image_tv:0.205149, image_mse:0.165534
# epoch:3000, feature_mse:0.328517, image_tv:0.175639, image_mse:0.102043
# epoch:4000, feature_mse:0.270903, image_tv:0.165416, image_mse:0.079317
# epoch:5000, feature_mse:0.253638, image_tv:0.162418, image_mse:0.072004
# epoch:6000, feature_mse:0.248019, image_tv:0.161554, image_mse:0.069823
# epoch:7000, feature_mse:0.246240, image_tv:0.161391, image_mse:0.069273
# epoch:8000, feature_mse:0.245708, image_tv:0.161452, image_mse:0.069212
# epoch:9000, feature_mse:0.245545, image_tv:0.161532, image_mse:0.069258
# psnr:17.614799

# %%
# 相同数据训练extractor，用虚假feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/server_same_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

x = model_inversion(net, fake_feature, lambda_tv=5)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# epoch:   0, feature_mse:60.680016, image_tv:0.000000, image_mse:0.511274
# epoch:1000, feature_mse:14.533345, image_tv:0.164442, image_mse:0.318223
# epoch:2000, feature_mse:0.985967, image_tv:0.228207, image_mse:0.150048
# epoch:3000, feature_mse:0.593194, image_tv:0.213655, image_mse:0.093373
# epoch:4000, feature_mse:0.494767, image_tv:0.214047, image_mse:0.073589
# epoch:5000, feature_mse:0.458237, image_tv:0.217501, image_mse:0.067731
# epoch:6000, feature_mse:0.442662, image_tv:0.220819, image_mse:0.066683
# epoch:7000, feature_mse:0.435881, image_tv:0.223381, image_mse:0.066890
# psnr:17.756972

# %%
# 同分布数据训练extractor，用虚假feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/server_iid_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

x = model_inversion(net, fake_feature, lambda_tv=50)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# epoch:   0, feature_mse:73.200325, image_tv:0.000000, image_mse:0.511268
# epoch:1000, feature_mse:34.939991, image_tv:0.778065, image_mse:0.370344
# epoch:2000, feature_mse:21.270838, image_tv:1.575218, image_mse:0.322468
# epoch:3000, feature_mse:20.102678, image_tv:1.938004, image_mse:0.344959
# psnr:10.464058

# %%
# 不同分布数据训练extractor，用虚假feature攻击

net = nn.ModuleDict()
net["extractor"] = Extractor()              
frozen_net(net, ["extractor"], True)

E_checkpoint = torch.load("./checkpoint/server_niid_extractor.pkl", map_location=torch.device('cpu'))
net["extractor"].load_state_dict(E_checkpoint)

x = model_inversion(net, fake_feature, lambda_tv=50)
print("psnr:%2.6f"%cal_psnr(image, x))
show_image(x)
# Out:
# epoch:   0, feature_mse:64.083832, image_tv:0.000000, image_mse:0.511352
# epoch:1000, feature_mse:38.944060, image_tv:1.011001, image_mse:0.365361
# epoch:2000, feature_mse:27.668836, image_tv:2.158030, image_mse:0.311022
# epoch:3000, feature_mse:26.591404, image_tv:2.502901, image_mse:0.302355
# epoch:4000, feature_mse:26.353944, image_tv:2.638456, image_mse:0.307148
# psnr:11.102064
